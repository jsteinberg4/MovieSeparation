# %% [markdown]
# # Initial dataset test w/ Neo4j

# %%
import logging
from neo4j import GraphDatabase
from neo4j.exceptions import ServiceUnavailable

log = logging.getLogger(__name__)

# %%
class TestApp:
    def __init__(self, uri, user, password):
        self._driver = None
        self._driver_conf = {
            'uri': uri,
            'auth': (user, password),
        }
        
    @property
    def driver(self):
        if self._driver is None:
            self._driver = GraphDatabase.driver(**self._driver_conf)
        return self._driver
    
    def close(self):
        # Always close the driver connection when done
        if self._driver is not None:
            self._driver.close()
            
    def create_friendship(self, person1_name, person2_name):
        with self.driver.session() as session:
            # Check api for write transactions
            result = session.write_transaction(
                self._create_and_return_friendship,
                person1_name, person2_name
            )
            for row in result:
                log.info(f"Created friendship: ({row['p1']})-[:KNOWS]->({row['p2']})")
                
    
    @staticmethod
    def _create_and_return_friendship(tx, person1_name, person2_name):
        # Query is a single long string, directly in Cypher syntax
        query = (
            "CREATE (p1: Person {name: $person1_name })"
            "CREATE (p2: Person {name: $person2_name })"
            "CREATE (p1)-[:KNOWS]->(p2)"
            "RETURN p1, p2"
        )
        # kwargs on run seem to allow mapping 'person1_name' to a value in the query
        result = tx.run(query, person1_name=person1_name, person2_name=person2_name)
        try:
            return [{"p1": row["p1"]["name"],
                    "p2": row["p2"]["name"]}
                   for row in result]
        except ServiceUnavailable as exception:
            log.error(f"{query} raised error:\n {exception}")
            raise
    
    def find_person(self, name):
        with self.driver.session() as session:
            result = session.read_transaction(self._find_and_return_person, name)
            for row in result:
                log.info(f"Found person: {row}")
            
    @staticmethod
    def _find_and_return_person(tx, name):
        query = (
            "MATCH (p: Person)"
            "WHERE p.name = $name"
            "RETURN p AS name"
        )
        result = tx.run(query, name=name)
        return [row["name"] for row in result]

# %%
bolt_url = "bolt://localhost:7687"
user = 'neo4j'
pwd = '12345'
app = TestApp(bolt_url, user, pwd)

# %%
app.create_friendship('Jesse', 'Andrew')
# Out:
# ---------------------------------------------------------------------------
# AuthError                                 Traceback (most recent call last)
# <ipython-input-4-a2d7f59c55d5> in <module>
# ----> 1 app.create_friendship('Jesse', 'Andrew')
#       2
#
# <ipython-input-2-11665e1d0f77> in create_friendship(self, person1_name, person2_name)
#      19
#      20     def create_friendship(self, person1_name, person2_name):
# ---> 21         with self.driver.session() as session:
#      22             # Check api for write transactions
#      23             result = session.write_transaction(
#
# <ipython-input-2-11665e1d0f77> in driver(self)
#      10     def driver(self):
#      11         if self._driver is None:
# ---> 12             self._driver = GraphDatabase.driver(**self._driver_conf)
#      13         return self._driver
#      14
#
# ~/.pyenv/versions/3.8.7/envs/bacon/lib/python3.8/site-packages/neo4j/__init__.py in driver(cls, uri, auth, **config)
#     181
#     182         if driver_type == DRIVER_BOLT:
# --> 183             return cls.bolt_driver(parsed.netloc, auth=auth, **config)
#     184         elif driver_type == DRIVER_NEO4j:
#     185             routing_context = parse_routing_context(parsed.query)
#
# ~/.pyenv/versions/3.8.7/envs/bacon/lib/python3.8/site-packages/neo4j/__init__.py in bolt_driver(cls, target, auth, **config)
#     194
#     195         try:
# --> 196             return BoltDriver.open(target, auth=auth, **config)
#     197         except (BoltHandshakeError, BoltSecurityError) as error:
#     198             from neo4j.exceptions import ServiceUnavailable
#
# ~/.pyenv/versions/3.8.7/envs/bacon/lib/python3.8/site-packages/neo4j/__init__.py in open(cls, target, auth, **config)
#     357         address = cls.parse_target(target)
#     358         pool_config, default_workspace_config = Config.consume_chain(config, PoolConfig, WorkspaceConfig)
# --> 359         pool = BoltPool.open(address, auth=auth, pool_config=pool_config, workspace_config=default_workspace_config)
#     360         return cls(pool, default_workspace_config)
#     361
#
# ~/.pyenv/versions/3.8.7/envs/bacon/lib/python3.8/site-packages/neo4j/io/__init__.py in open(cls, address, auth, pool_config, workspace_config, routing_context)
#     533
#     534         pool = cls(opener, pool_config, workspace_config, routing_context, address)
# --> 535         seeds = [pool.acquire() for _ in range(pool_config.init_size)]
#     536         pool.release(*seeds)
#     537         return pool
#
# ~/.pyenv/versions/3.8.7/envs/bacon/lib/python3.8/site-packages/neo4j/io/__init__.py in <listcomp>(.0)
#     533
#     534         pool = cls(opener, pool_config, workspace_config, routing_context, address)
# --> 535         seeds = [pool.acquire() for _ in range(pool_config.init_size)]
#     536         pool.release(*seeds)
#     537         return pool
#
# ~/.pyenv/versions/3.8.7/envs/bacon/lib/python3.8/site-packages/neo4j/io/__init__.py in acquire(self, access_mode, timeout, database)
#     547     def acquire(self, access_mode=None, timeout=None, database=None):
#     548         # The access_mode and database is not needed for a direct connection, its just there for consistency.
# --> 549         return self._acquire(self.address, timeout)
#     550
#     551
#
# ~/.pyenv/versions/3.8.7/envs/bacon/lib/python3.8/site-packages/neo4j/io/__init__.py in _acquire(self, address, timeout)
#     411                     timeout = min(self.pool_config.connection_timeout, time_remaining())
#     412                     try:
# --> 413                         connection = self.opener(address, timeout)
#     414                     except ServiceUnavailable:
#     415                         self.remove(address)
#
# ~/.pyenv/versions/3.8.7/envs/bacon/lib/python3.8/site-packages/neo4j/io/__init__.py in opener(addr, timeout)
#     530
#     531         def opener(addr, timeout):
# --> 532             return Bolt.open(addr, auth=auth, timeout=timeout, routing_context=routing_context, **pool_config)
#     533
#     534         pool = cls(opener, pool_config, workspace_config, routing_context, address)
#
# ~/.pyenv/versions/3.8.7/envs/bacon/lib/python3.8/site-packages/neo4j/io/__init__.py in open(cls, address, auth, timeout, routing_context, **pool_config)
#     229             s.shutdown(SHUT_RDWR)
#     230             s.close()
# --> 231             raise error
#     232
#     233         return connection
#
# ~/.pyenv/versions/3.8.7/envs/bacon/lib/python3.8/site-packages/neo4j/io/__init__.py in open(cls, address, auth, timeout, routing_context, **pool_config)
#     224
#     225         try:
# --> 226             connection.hello()
#     227         except Exception as error:
#     228             log.debug("[#%04X]  C: <CLOSE> %s", s.getsockname()[1], str(error))
#
# ~/.pyenv/versions/3.8.7/envs/bacon/lib/python3.8/site-packages/neo4j/io/_bolt4.py in hello(self)
#     156                      response=InitResponse(self, on_success=self.server_info._update_metadata))
#     157         self.send_all()
# --> 158         self.fetch_all()
#     159
#     160     def run(self, query, parameters=None, mode=None, bookmarks=None, metadata=None, timeout=None, db=None, **handlers):
#
# ~/.pyenv/versions/3.8.7/envs/bacon/lib/python3.8/site-packages/neo4j/io/_bolt4.py in fetch_all(self)
#     427             response = self.responses[0]
#     428             while not response.complete:
# --> 429                 detail_delta, summary_delta = self.fetch_message()
#     430                 detail_count += detail_delta
#     431                 summary_count += summary_delta
#
# ~/.pyenv/versions/3.8.7/envs/bacon/lib/python3.8/site-packages/neo4j/io/_bolt4.py in fetch_message(self)
#     361             log.debug("[#%04X]  S: FAILURE %r", self.local_port, summary_metadata)
#     362             try:
# --> 363                 response.on_failure(summary_metadata or {})
#     364             except (ServiceUnavailable, DatabaseUnavailable):
#     365                 if self.pool:
#
# ~/.pyenv/versions/3.8.7/envs/bacon/lib/python3.8/site-packages/neo4j/io/_common.py in on_failure(self, metadata)
#     196         message = metadata.get("message", "Connection initialisation failed")
#     197         if code == "Neo.ClientError.Security.Unauthorized":
# --> 198             raise AuthError(message)
#     199         else:
#     200             raise ServiceUnavailable(message)
#
# AuthError: {code: None} {message: None}

# %%
app.close()
